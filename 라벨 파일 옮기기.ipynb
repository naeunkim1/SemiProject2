# %%
flist=['현미밥',
'물냉면',
'비빔냉면',
'수제비',
'소고기무국',
'시래기된장국',
'된장찌개',
'참치김치찌개',
'찜닭',
'두부구이',
'파전',
'멸치볶음',
'고등어조림',
'도토리묵',
'가지나물',
'시금치나물']

# %%
nlist=['01012005',
'02011013',
'02011015',
'02011019',
'04011007',
'04012008',
'04017001',
'04019003',
'05012004',
'06013003',
'07013011',
'08011003',
'09011003',
'11011006',
'11013001',
'11013007']

# %%
from tqdm import tqdm
import os
import glob
from distutils.dir_util import copy_tree

train_path="C:/Users/fluor/pro/새 폴더/[라벨]음식분류_TRAIN/txt/"
test_path="C:/Users/fluor/pro/새 폴더/[라벨]음식분류_VAL/txt/"


for i in tqdm(range(len(flist))):
    train_label_folder='d:/'+flist[i]+'/train/labels/'
    tr_label_folder=train_path+nlist[i]
    copy_tree(tr_label_folder, train_label_folder)
    
    test_label_folder='d:/'+flist[i]+'/test/labels/'
    te_label_folder=test_path+nlist[i]
    copy_tree(te_label_folder, test_label_folder)
# Out:
#  88%|███████████████████████████████████████████████████████████████████████▊          | 14/16 [22:34<03:15, 97.78s/it]

# %%
a=[1,2,3,4]
b=[5,6,7,8]

for n in a,b:
    print(n)
# Out:
# [1, 2, 3, 4]
# [5, 6, 7, 8]

# %%
for n in nlist:
    t_label_folder=os.listdir('C:\Users\fluor\pro\새 폴더\[라벨]음식분류_TRAIN\txt\'+str(8011003))

    print(''
C:\Users\fluor\pro\새 폴더\[라벨]음식분류_TRAIN\txt

# %%
path="C:/Users/fluor/pro/새 폴더/[라벨]음식분류_TRAIN/txt/"

# %%
t_label_folder=os.listdir(path+'08011003')
    
print(t_label_folder)
# Out:
# ['08_081_08011003_160273190547378.txt', '08_081_08011003_160273193514127.txt', '08_081_08011003_160273558475440.txt', '08_081_08011003_160273864311912.txt', '08_081_08011003_160273866521562.txt', '08_081_08011003_160273873473536.txt', '08_081_08011003_160273878468433.txt', '08_081_08011003_160273935015459.txt', '08_081_08011003_160273936532291.txt', '08_081_08011003_160273986047675.txt', '08_081_08011003_160274020976715.txt', '08_081_08011003_160274023996699.txt', '08_081_08011003_160274034368876.txt', '08_081_08011003_160274037973565.txt', '08_081_08011003_160274071290914.txt', '08_081_08011003_160274118941256.txt', '08_081_08011003_160274121011854.txt', '08_081_08011003_160274227179020.txt', '08_081_08011003_160274263562999.txt', '08_081_08011003_160274266996253.txt', '08_081_08011003_160274413888779.txt', '08_081_08011003_160274568660913.txt', '08_081_08011003_160274570664962.txt', '08_081_08011003_160274690751275.txt', '08_081_08011003_160274701151098.txt', '08_081_08011003_16027
# ...
